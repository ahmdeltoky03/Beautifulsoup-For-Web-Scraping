# %% [markdown]
# # `Books to Scrape`

# %% [markdown]
# ## **URL** =  https://books.toscrape.com/catalogue/category/books/travel_2/index.html

# %% [markdown]
# This is a library in which a group of books is displayed,
# and each group of books falls under a specific concept.
# For example, books related to travel, mysteries, children...etc.
# If you want to search for a specific type of book,
# enter the URL of the subject at the top,
# and then choose the type. What is required,
# copy the URL and put it in the requested URL.
# Once run all cells in Jupter is done,
# the books are collected in a CSV file
# with the name of the chosen type and kept on the device.

# %%
## import main libraries
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
## Enter Your which  url you want to extract data from it
requried_url = 'https://books.toscrape.com/catalogue/category/books/travel_2/index.html'
response = requests.get(requried_url)

# %%
response.content
# response.text
# Out:
# b'\n\n<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    Travel | \n     Books to Scrape - Sandbox\n\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="\n    \n" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="s
# ...

# %%
soup = BeautifulSoup(response.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     Travel |
#      Books to Scrape - Sandbox
#
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="
#
# " name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="../../../../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
## Title of Any Backage of Books
_title = soup.find('title').get_text().strip().split(' | ')[0]
_title
# Out:
# 'Travel'

# %%
_title
# Out:
# 'Travel'

# %%
books = soup.find_all('li',attrs = {'class':'col-xs-6 col-sm-4 col-md-3 col-lg-3'})
books
# Out:
# [<li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="../../../its-only-the-himalayas_981/index.html"><img alt="It's Only the Himalayas" class="thumbnail" src="../../../../media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg"/></a>
#  </div>
#  <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">It's Only the Himalayas</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£45.17</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>
#  </li>,
# ...

# %%
## books_Name
books_name = []
for book in books:
    books_name.append((book.find('h3').find('a').get('title')))
    # print(book.find('h3').find('a').get('title'))
    # print('-'*100)

## books_Price
books_price = []
for book in books:
    books_price.append(book.find('p',attrs={'class':"price_color"}).get_text()[2:])
    # print(book.find('p',attrs={'class':"price_color"}).get_text())
    # print('-'*100)

## books_Rate
books_rate = []
for book in books:
    books_rate.append(book.find('p',attrs={'class':'star-rating'}).get('class')[-1])
    # books_rate.append(book.find('p').get('class')[-1])
    # print(book.find('p',attrs={'class':'star-rating'}).get('class')[-1])
    # print('-'*100)

## create CSV file
_fieldnames = ['Books_Name','Books_Price','Books_Rate']
with open (f'{_title}.csv','w',newline='',encoding='utf-8') as f:
    writer = csv.DictWriter(f,fieldnames=_fieldnames)
    writer.writeheader()
    for name,price,rate in zip(books_name,books_price,books_rate):
        writer.writerow({'Books_Name':name,
                         'Books_Price':price,
                         'Books_Rate':rate})
## Read CSV file using Pandas
book_store = pd.read_csv(f'{_title}.csv')

# %%
book_store
# Out:
#                                            Books_Name  Books_Price Books_Rate
# 0                             It's Only the Himalayas        45.17        Two
# 1   Full Moon over Noahâs Ark: An Odyssey to Mou...        49.43       Four
# 2   See America: A Celebration of Our National Par...        48.87      Three
# 3   Vagabonding: An Uncommon Guide to the Art of L...        36.94        Two
# 4                                Under the Tuscan Sun        37.33      Three
# 5                                  A Summer In Europe        44.34        Two
# 6                            The Great Railway Bazaar        30.54        One
# 7                    A Year in Provence (Provence #1)        56.88       Four
# 8   The Road to Little Dribbling: Adventures of an...        23.21        One
# 9           Neither Here nor There: Travels in Europe        38.95      Three
# 10                 1,000 Places to See Before You Die        26.08       Five

# %%
## Average price of the book (Mean)
# Average = sum(books_price)/len(books_price)
summation_of_price = 0
for price in books_price:
    summation_of_price += float(price)
summation_of_price/len(books_price) ## mean
# Out:
# 39.79454545454546

# %%
## Average price of the book (Mean)
book_store['Books_Price'].mean()
# Out:
# 39.79454545454545
